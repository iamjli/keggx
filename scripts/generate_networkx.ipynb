# %%
import pandas as pd
import networkx as nx

import xml.etree.ElementTree as ET

from itertools import combinations

# %%
def get_node_attributes_from_entry(entry): 
    
    node_attributes = {
        "type": entry.get("type"), # i.e. 'gene'
        "id": int(entry.get("id")) # i.e. 84
    }
    
    # If compound node (protein complexes)
    if node_attributes["type"] == "group": 
        node_attributes["components"] = [int(x.get("id")) for x in entry.findall("component")]
        return node_attributes 
    else: 
        node_attributes["aliases"] = entry[0].get("name") # i.e. 'ALDOA, ALDA, GSD12, HEL-S-87p...'
        node_attributes["hsa_tags"] = entry.get("name") # i.e. 'hsa:226 hsa:229 hsa:230'
        node_attributes["first_name"] = node_attributes["aliases"].split(", ")[0].split("...")[0] # i.e. 'ALDOA'
    
    return node_attributes


def get_edge_attributes_from_entry(entry):
    
    edge_attributes = {
        "node1": int(entry.get("entry1")),
        "node2": int(entry.get("entry2")),
        "type": entry.get("type")
    }
    
    for attribute in entry: 
        
        interaction = attribute.get("name")
        
        if interaction in ["activation", "expression", "indirect effect"]: 
            edge_attributes["sign"] = 1
        elif interaction in ["inhibition", "repression"]: 
            edge_attributes["sign"] = -1
        elif interaction in ["binding/association"]: 
            edge_attributes["sign"] = 0
            
        elif interaction == "phosphorylation": 
            edge_attributes["phosphorylation"] = 1
        elif interaction == "dephosphorylation": 
            edge_attributes["phosphorylation"] = -1
            
        elif interaction == "glycosylation":
            edge_attributes["glycosylation"] = 1
            
        elif interaction == "ubiquitination": 
            edge_attributes["ubiquitination"] = 1
            
        elif interaction == "methylation": 
            edge_attributes["methylation"] = 1
        
        # Force edge through compound node. Unfortunately, these interactions are poorly annotated in KGML.
        # These should be of type "ECrel", but may be mistakenly annotated as "PPrel" in KGMLs.
        elif interaction == "compound": 
            edge1 = {"node1": edge_attributes["node1"], "node2": int(attribute.get("value")), "type": "ECrel"}
            edge2 = {"node2": edge_attributes["node2"], "node2": int(attribute.get("value")), "type": "ECrel"}
        
        else: 
            print(interaction)
            
        # Fill in sign for implicit interactions
        if len(set(edge_attributes.keys()) & set(["phosphorylation", "glycosylation", "ubiquitination", "methylation"])) > 0:
            edge_attributes["sign"] = 1
            
    return edge_attributes


def replace_group_edges(edge_attributes_df, group_obj):
    
    group_id = group_obj["id"] 
    group_members = group_obj["components"]
    n_members = len(group_members)
    initial_length = len(edge_attributes_df)
    
    # Split into two dataframes based on `node1` column
    edges_without_df = edge_attributes_df[edge_attributes_df["node1"] != group_id]
    edges_with_df = edge_attributes_df[edge_attributes_df["node1"] == group_id]
    # Duplicate rows where `node1` contains the `group_id`
    expanded_edges_df = pd.concat([edges_with_df]*n_members).sort_index() 
    # Replace `node` column with repeating list of `group_members`
    expanded_edges_df["node1"] = group_members*len(edges_with_df)
    # Concatenate the new dataframes and reset index
    edge_attributes_df = pd.concat([expanded_edges_df, edges_without_df]).reset_index(drop=True)
    
    # Do the same procedure with `node2` column
    edges_without_df = edge_attributes_df[edge_attributes_df["node2"] != group_id]
    edges_with_df = edge_attributes_df[edge_attributes_df["node2"] == group_id]
    expanded_edges_df = pd.concat([edges_with_df]*n_members).sort_index() 
    expanded_edges_df["node2"] = group_members*len(edges_with_df)
    edge_attributes_df = pd.concat([expanded_edges_df, edges_without_df]).reset_index(drop=True)
    
    # Add edges between group members. `sign` will implicity be assigned 0 to indicate no directionality. 
    group_rows = [{"node1": a, "node2": b, "type":"complex"} for a,b in combinations(group_members, 2)]
    edge_attributes_df = edge_attributes_df.append(group_rows, ignore_index=True).fillna(0)
    
#     print("{} members in group {}. {} edges added.".format(n_members, group_id, len(edge_attributes_df)-initial_length))
        
    return edge_attributes_df

# %%
def get_KGML_as_networkx(path):
    
    # Open XML as elementtree object
    tree = ET.parse(path)
    root = tree.getroot()
    
    print(root.attrib)

    # Define node and edge elements
    node_elements  = [elem for elem in root.findall("entry") if elem.get("type") != "group"] # alternatively `root.findall("./entry[@type='group']")`
    group_elements = [elem for elem in root.findall("entry") if elem.get("type") == "group"]
    edge_elements  = root.findall("relation")
    
    # Get node, group and edge attributes
    node_attributes = [get_node_attributes_from_entry(element) for element in node_elements]
    node_attributes_df = pd.DataFrame(node_attributes).set_index("id")

    group_attributes = [get_node_attributes_from_entry(element) for element in group_elements]
    
    edge_attributes_df = pd.DataFrame([get_edge_attributes_from_entry(x) for x in edge_elements if x.get("type") in ["PPrel", "CRel"]])
    
    # Replace group nodes with individual components and update edge_attributes
    for group_attribute in group_attributes: 
        edge_attributes_df = replace_group_edges(edge_attributes_df, group_attribute)
        
    # Create directed networkx graph
    G_dir = nx.DiGraph()
    G_dir.add_nodes_from([(key, dic) for key, dic in node_attributes_df.to_dict("index").items()])
    G_dir.add_edges_from([(row["node1"], row["node2"], row[edge_attributes_df.columns[2:]].to_dict()) for _,row in edge_attributes_df.iterrows()])
    nx.relabel_nodes(G_dir, {node_id:G_dir.node[node_id]["first_name"] for node_id in G_dir.nodes()}, copy=False)

    # Create undirected networkx graph. Useful for finding interactions with ambiguous direction
    G_und = nx.Graph()
    G_und.add_nodes_from([(key, dic) for key, dic in node_attributes_df.to_dict("index").items()])
    G_und.add_edges_from([(row["node1"], row["node2"], row[edge_attributes_df.columns[2:]].to_dict()) for _,row in edge_attributes_df.iterrows()])
    nx.relabel_nodes(G_und, {node_id:G_und.node[node_id]["first_name"] for node_id in G_und.nodes()}, copy=False)
    
    out = {"directed": G_dir, "undirected": G_und}
    out = {**out, **root.attrib}
    
    return out

# %%
from glob import glob
from os.path import basename

paths = glob("../data/human_KGML/*.xml")

# graphs = {basename(path).split(".")[0]: get_KGML_as_networkx(path) for path in paths}
graphs = {}
for path in paths: 
    try: 
        tag = basename(path).split(".")[0]
        graphs[tag] = get_KGML_as_networkx(path)
    except: 
        pass
# Out:
# {'name': 'path:hsa04371', 'org': 'hsa', 'number': '04371', 'title': 'Apelin signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04371.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04371'}
# {'name': 'path:hsa04211', 'org': 'hsa', 'number': '04211', 'title': 'Longevity regulating pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04211.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04211'}
# {'name': 'path:hsa05133', 'org': 'hsa', 'number': '05133', 'title': 'Pertussis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05133.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05133'}
# {'name': 'path:hsa05132', 'org': 'hsa', 'number': '05132', 'title': 'Salmonella infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05132.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05132'}
# {'name': 'path:hsa00062', 'org': 'hsa', 'number': '00062', 'title': 'Fatty acid elongation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00062.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00062'}
# {'name': 'path:hsa04210', 'org': 'hsa', 'number': '04210', 'title': 'Apoptosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04210.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04210'}
# dissociation
# {'name': 'path:hsa05330', 'org': 'hsa', 'number': '05330', 'title': 'Allograft rejection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05330.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05330'}
# {'name': 'path:hsa00260', 'org': 'hsa', 'number': '00260', 'title': 'Glycine, serine and threonine metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00260.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00260'}
# {'name': 'path:hsa04012', 'org': 'hsa', 'number': '04012', 'title': 'ErbB signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04012.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04012'}
# {'name': 'path:hsa00512', 'org': 'hsa', 'number': '00512', 'title': 'Mucin type O-glycan biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00512.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00512'}
# {'name': 'path:hsa00472', 'org': 'hsa', 'number': '00472', 'title': 'D-Arginine and D-ornithine metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00472.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00472'}
# {'name': 'path:hsa04614', 'org': 'hsa', 'number': '04614', 'title': 'Renin-angiotensin system', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04614.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04614'}
# {'name': 'path:hsa04370', 'org': 'hsa', 'number': '04370', 'title': 'VEGF signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04370.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04370'}
# {'name': 'path:hsa00670', 'org': 'hsa', 'number': '00670', 'title': 'One carbon pool by folate', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00670.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00670'}
# {'name': 'path:hsa00100', 'org': 'hsa', 'number': '00100', 'title': 'Steroid biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00100.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00100'}
# {'name': 'path:hsa00510', 'org': 'hsa', 'number': '00510', 'title': 'N-Glycan biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00510.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00510'}
# {'name': 'path:hsa04010', 'org': 'hsa', 'number': '04010', 'title': 'MAPK signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04010.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04010'}
# {'name': 'path:hsa05332', 'org': 'hsa', 'number': '05332', 'title': 'Graft-versus-host disease', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05332.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05332'}
# missing interaction
# {'name': 'path:hsa04979', 'org': 'hsa', 'number': '04979', 'title': 'Cholesterol metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04979.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04979'}
# {'name': 'path:hsa05130', 'org': 'hsa', 'number': '05130', 'title': 'Pathogenic Escherichia coli infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05130.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05130'}
# dissociation
# {'name': 'path:hsa00920', 'org': 'hsa', 'number': '00920', 'title': 'Sulfur metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00920.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00920'}
# {'name': 'path:hsa05131', 'org': 'hsa', 'number': '05131', 'title': 'Shigellosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05131.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05131'}
# dissociation
# {'name': 'path:hsa04213', 'org': 'hsa', 'number': '04213', 'title': 'Longevity regulating pathway - multiple species', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04213.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04213'}
# {'name': 'path:hsa00061', 'org': 'hsa', 'number': '00061', 'title': 'Fatty acid biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00061.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00061'}
# {'name': 'path:hsa04950', 'org': 'hsa', 'number': '04950', 'title': 'Maturity onset diabetes of the young', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04950.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04950'}
# {'name': 'path:hsa04978', 'org': 'hsa', 'number': '04978', 'title': 'Mineral absorption', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04978.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04978'}
# {'name': 'path:hsa03030', 'org': 'hsa', 'number': '03030', 'title': 'DNA replication', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03030.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03030'}
# {'name': 'path:hsa03018', 'org': 'hsa', 'number': '03018', 'title': 'RNA degradation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03018.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03018'}
# {'name': 'path:hsa00511', 'org': 'hsa', 'number': '00511', 'title': 'Other glycan degradation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00511.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00511'}
# {'name': 'path:hsa00471', 'org': 'hsa', 'number': '00471', 'title': 'D-Glutamine and D-glutamate metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00471.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00471'}
# {'name': 'path:hsa03420', 'org': 'hsa', 'number': '03420', 'title': 'Nucleotide excision repair', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03420.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03420'}
# {'name': 'path:hsa03430', 'org': 'hsa', 'number': '03430', 'title': 'Mismatch repair', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03430.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03430'}
# {'name': 'path:hsa05323', 'org': 'hsa', 'number': '05323', 'title': 'Rheumatoid arthritis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05323.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05323'}
# {'name': 'path:hsa03020', 'org': 'hsa', 'number': '03020', 'title': 'RNA polymerase', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03020.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03020'}
# {'name': 'path:hsa03008', 'org': 'hsa', 'number': '03008', 'title': 'Ribosome biogenesis in eukaryotes', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03008.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03008'}
# {'name': 'path:hsa04015', 'org': 'hsa', 'number': '04015', 'title': 'Rap1 signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04015.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04015'}
# {'name': 'path:hsa00515', 'org': 'hsa', 'number': '00515', 'title': 'Mannose type O-glycan biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00515.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00515'}
# {'name': 'path:hsa04940', 'org': 'hsa', 'number': '04940', 'title': 'Type I diabetes mellitus', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04940.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04940'}
# {'name': 'path:hsa00071', 'org': 'hsa', 'number': '00071', 'title': 'Fatty acid degradation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00071.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00071'}
# {'name': 'path:hsa04217', 'org': 'hsa', 'number': '04217', 'title': 'Necroptosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04217.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04217'}
# {'name': 'path:hsa04216', 'org': 'hsa', 'number': '04216', 'title': 'Ferroptosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04216.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04216'}
# {'name': 'path:hsa05134', 'org': 'hsa', 'number': '05134', 'title': 'Legionellosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05134.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05134'}
# dissociation
# {'name': 'path:hsa05120', 'org': 'hsa', 'number': '05120', 'title': 'Epithelial cell signaling in Helicobacter pylori infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05120.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05120'}
# dissociation
# {'name': 'path:hsa04014', 'org': 'hsa', 'number': '04014', 'title': 'Ras signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04014.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04014'}
# {'name': 'path:hsa00514', 'org': 'hsa', 'number': '00514', 'title': 'Other types of O-glycan biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00514.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00514'}
# {'name': 'path:hsa00500', 'org': 'hsa', 'number': '00500', 'title': 'Starch and sucrose metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00500.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00500'}
# {'name': 'path:hsa05322', 'org': 'hsa', 'number': '05322', 'title': 'Systemic lupus erythematosus', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05322.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05322'}
# {'name': 'path:hsa04612', 'org': 'hsa', 'number': '04612', 'title': 'Antigen processing and presentation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04612.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04612'}
# state change
# state change
# state change
# state change
# state change
# state change
# state change
# state change
# state change
# {'name': 'path:hsa01230', 'org': 'hsa', 'number': '01230', 'title': 'Biosynthesis of amino acids', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01230.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01230'}
# {'name': 'path:hsa04360', 'org': 'hsa', 'number': '04360', 'title': 'Axon guidance', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04360.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04360'}
# {'name': 'path:hsa00310', 'org': 'hsa', 'number': '00310', 'title': 'Lysine degradation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00310.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00310'}
# {'name': 'path:hsa04610', 'org': 'hsa', 'number': '04610', 'title': 'Complement and coagulation cascades', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04610.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04610'}
# {'name': 'path:hsa05320', 'org': 'hsa', 'number': '05320', 'title': 'Autoimmune thyroid disease', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05320.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05320'}
# {'name': 'path:hsa00270', 'org': 'hsa', 'number': '00270', 'title': 'Cysteine and methionine metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00270.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00270'}
# {'name': 'path:hsa00072', 'org': 'hsa', 'number': '00072', 'title': 'Synthesis and degradation of ketone bodies', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00072.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00072'}
# {'name': 'path:hsa04215', 'org': 'hsa', 'number': '04215', 'title': 'Apoptosis - multiple species', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04215.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04215'}
# {'name': 'path:hsa05321', 'org': 'hsa', 'number': '05321', 'title': 'Inflammatory bowel disease (IBD)', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05321.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05321'}
# {'name': 'path:hsa03022', 'org': 'hsa', 'number': '03022', 'title': 'Basal transcription factors', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03022.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03022'}
# {'name': 'path:hsa04611', 'org': 'hsa', 'number': '04611', 'title': 'Platelet activation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04611.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04611'}
# {'name': 'path:hsa01524', 'org': 'hsa', 'number': '01524', 'title': 'Platinum drug resistance', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01524.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01524'}
# {'name': 'path:hsa05030', 'org': 'hsa', 'number': '05030', 'title': 'Cocaine addiction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05030.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05030'}
# {'name': 'path:hsa04662', 'org': 'hsa', 'number': '04662', 'title': 'B cell receptor signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04662.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04662'}
# dissociation
# {'name': 'path:hsa04110', 'org': 'hsa', 'number': '04110', 'title': 'Cell cycle', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04110.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04110'}
# dissociation
# dissociation
# {'name': 'path:hsa00410', 'org': 'hsa', 'number': '00410', 'title': 'beta-Alanine metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00410.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00410'}
# {'name': 'path:hsa05226', 'org': 'hsa', 'number': '05226', 'title': 'Gastric cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05226.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05226'}
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# dissociation
# {'name': 'path:hsa01040', 'org': 'hsa', 'number': '01040', 'title': 'Biosynthesis of unsaturated fatty acids', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01040.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01040'}
# {'name': 'path:hsa04070', 'org': 'hsa', 'number': '04070', 'title': 'Phosphatidylinositol signaling system', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04070.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04070'}
# {'name': 'path:hsa04064', 'org': 'hsa', 'number': '04064', 'title': 'NF-kappa B signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04064.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04064'}
# dissociation
# dissociation
# dissociation
# {'name': 'path:hsa00564', 'org': 'hsa', 'number': '00564', 'title': 'Glycerophospholipid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00564.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00564'}
# {'name': 'path:hsa04919', 'org': 'hsa', 'number': '04919', 'title': 'Thyroid hormone signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04919.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04919'}
# {'name': 'path:hsa04931', 'org': 'hsa', 'number': '04931', 'title': 'Insulin resistance', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04931.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04931'}
# {'name': 'path:hsa04925', 'org': 'hsa', 'number': '04925', 'title': 'Aldosterone synthesis and secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04925.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04925'}
# {'name': 'path:hsa04514', 'org': 'hsa', 'number': '04514', 'title': 'Cell adhesion molecules (CAMs)', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04514.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04514'}
# {'name': 'path:hsa05150', 'org': 'hsa', 'number': '05150', 'title': 'Staphylococcus aureus infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05150.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05150'}
# {'name': 'path:hsa00982', 'org': 'hsa', 'number': '00982', 'title': 'Drug metabolism - cytochrome P450', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00982.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00982'}
# {'name': 'path:hsa05144', 'org': 'hsa', 'number': '05144', 'title': 'Malaria', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05144.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05144'}
# {'name': 'path:hsa00983', 'org': 'hsa', 'number': '00983', 'title': 'Drug metabolism - other enzymes', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00983.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00983'}
# {'name': 'path:hsa05145', 'org': 'hsa', 'number': '05145', 'title': 'Toxoplasmosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05145.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05145'}
# dissociation
# {'name': 'path:hsa04924', 'org': 'hsa', 'number': '04924', 'title': 'Renin secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04924.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04924'}
# {'name': 'path:hsa04930', 'org': 'hsa', 'number': '04930', 'title': 'Type II diabetes mellitus', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04930.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04930'}
# {'name': 'path:hsa04918', 'org': 'hsa', 'number': '04918', 'title': 'Thyroid hormone synthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04918.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04918'}
# {'name': 'path:hsa03050', 'org': 'hsa', 'number': '03050', 'title': 'Proteasome', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03050.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03050'}
# {'name': 'path:hsa00565', 'org': 'hsa', 'number': '00565', 'title': 'Ether lipid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00565.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00565'}
# {'name': 'path:hsa04071', 'org': 'hsa', 'number': '04071', 'title': 'Sphingolipid signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04071.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04071'}
# {'name': 'path:hsa05031', 'org': 'hsa', 'number': '05031', 'title': 'Amphetamine addiction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05031.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05031'}
# {'name': 'path:hsa03440', 'org': 'hsa', 'number': '03440', 'title': 'Homologous recombination', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03440.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03440'}
# {'name': 'path:hsa02010', 'org': 'hsa', 'number': '02010', 'title': 'ABC transporters', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa02010.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa02010'}
# {'name': 'path:hsa05033', 'org': 'hsa', 'number': '05033', 'title': 'Nicotine addiction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05033.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05033'}
# {'name': 'path:hsa05219', 'org': 'hsa', 'number': '05219', 'title': 'Bladder cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05219.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05219'}
# dissociation
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa05231', 'org': 'hsa', 'number': '05231', 'title': 'Choline metabolism in cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05231.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05231'}
# {'name': 'path:hsa05225', 'org': 'hsa', 'number': '05225', 'title': 'Hepatocellular carcinoma', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05225.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05225'}
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# dissociation
# missing interaction
# {'name': 'path:hsa04926', 'org': 'hsa', 'number': '04926', 'title': 'Relaxin signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04926.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04926'}
# dissociation
# dissociation
# {'name': 'path:hsa04932', 'org': 'hsa', 'number': '04932', 'title': 'Non-alcoholic fatty liver disease (NAFLD)', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04932.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04932'}
# {'name': 'path:hsa05152', 'org': 'hsa', 'number': '05152', 'title': 'Tuberculosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05152.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05152'}
# dissociation
# {'name': 'path:hsa05146', 'org': 'hsa', 'number': '05146', 'title': 'Amoebiasis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05146.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05146'}
# {'name': 'path:hsa00980', 'org': 'hsa', 'number': '00980', 'title': 'Metabolism of xenobiotics by cytochrome P450', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00980.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00980'}
# {'name': 'path:hsa00770', 'org': 'hsa', 'number': '00770', 'title': 'Pantothenate and CoA biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00770.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00770'}
# {'name': 'path:hsa04270', 'org': 'hsa', 'number': '04270', 'title': 'Vascular smooth muscle contraction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04270.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04270'}
# dissociation
# {'name': 'path:hsa04933', 'org': 'hsa', 'number': '04933', 'title': 'AGE-RAGE signaling pathway in diabetic complications', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04933.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04933'}
# {'name': 'path:hsa04927', 'org': 'hsa', 'number': '04927', 'title': 'Cortisol synthesis and secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04927.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04927'}
# {'name': 'path:hsa04728', 'org': 'hsa', 'number': '04728', 'title': 'Dopaminergic synapse', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04728.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04728'}
# {'name': 'path:hsa04072', 'org': 'hsa', 'number': '04072', 'title': 'Phospholipase D signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04072.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04072'}
# {'name': 'path:hsa04714', 'org': 'hsa', 'number': '04714', 'title': 'Thermogenesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04714.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04714'}
# {'name': 'path:hsa04066', 'org': 'hsa', 'number': '04066', 'title': 'HIF-1 signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04066.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04066'}
# {'name': 'path:hsa05224', 'org': 'hsa', 'number': '05224', 'title': 'Breast cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05224.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05224'}
# dissociation
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa05230', 'org': 'hsa', 'number': '05230', 'title': 'Central carbon metabolism in cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05230.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05230'}
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa05218', 'org': 'hsa', 'number': '05218', 'title': 'Melanoma', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05218.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05218'}
# dissociation
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa00360', 'org': 'hsa', 'number': '00360', 'title': 'Phenylalanine metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00360.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00360'}
# {'name': 'path:hsa04660', 'org': 'hsa', 'number': '04660', 'title': 'T cell receptor signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04660.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04660'}
# dissociation
# {'name': 'path:hsa05032', 'org': 'hsa', 'number': '05032', 'title': 'Morphine addiction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05032.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05032'}
# {'name': 'path:hsa00604', 'org': 'hsa', 'number': '00604', 'title': 'Glycosphingolipid biosynthesis - ganglio series', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00604.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00604'}
# {'name': 'path:hsa04310', 'org': 'hsa', 'number': '04310', 'title': 'Wnt signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04310.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04310'}
# dissociation
# {'name': 'path:hsa01522', 'org': 'hsa', 'number': '01522', 'title': 'Endocrine resistance', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01522.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01522'}
# {'name': 'path:hsa00600', 'org': 'hsa', 'number': '00600', 'title': 'Sphingolipid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00600.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00600'}
# {'name': 'path:hsa04658', 'org': 'hsa', 'number': '04658', 'title': 'Th1 and Th2 cell differentiation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04658.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04658'}
# dissociation
# {'name': 'path:hsa05220', 'org': 'hsa', 'number': '05220', 'title': 'Chronic myeloid leukemia', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05220.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05220'}
# dissociation
# dissociation
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa04670', 'org': 'hsa', 'number': '04670', 'title': 'Leukocyte transendothelial migration', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04670.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04670'}
# dissociation
# dissociation
# {'name': 'path:hsa04664', 'org': 'hsa', 'number': '04664', 'title': 'Fc epsilon RI signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04664.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04664'}
# {'name': 'path:hsa05340', 'org': 'hsa', 'number': '05340', 'title': 'Primary immunodeficiency', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05340.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05340'}
# {'name': 'path:hsa04062', 'org': 'hsa', 'number': '04062', 'title': 'Chemokine signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04062.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04062'}
# dissociation
# dissociation
# {'name': 'path:hsa00562', 'org': 'hsa', 'number': '00562', 'title': 'Inositol phosphate metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00562.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00562'}
# {'name': 'path:hsa04710', 'org': 'hsa', 'number': '04710', 'title': 'Circadian rhythm', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04710.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04710'}
# {'name': 'path:hsa04923', 'org': 'hsa', 'number': '04923', 'title': 'Regulation of lipolysis in adipocytes', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04923.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04923'}
# {'name': 'path:hsa05142', 'org': 'hsa', 'number': '05142', 'title': 'Chagas disease (American trypanosomiasis)', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05142.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05142'}
# {'name': 'path:hsa00760', 'org': 'hsa', 'number': '00760', 'title': 'Nicotinate and nicotinamide metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00760.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00760'}
# {'name': 'path:hsa04260', 'org': 'hsa', 'number': '04260', 'title': 'Cardiac muscle contraction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04260.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04260'}
# dissociation
# dissociation
# {'name': 'path:hsa04512', 'org': 'hsa', 'number': '04512', 'title': 'ECM-receptor interaction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04512.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04512'}
# {'name': 'path:hsa04261', 'org': 'hsa', 'number': '04261', 'title': 'Adrenergic signaling in cardiomyocytes', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04261.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04261'}
# dissociation
# {'name': 'path:hsa05143', 'org': 'hsa', 'number': '05143', 'title': 'African trypanosomiasis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05143.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05143'}
# {'name': 'path:hsa04922', 'org': 'hsa', 'number': '04922', 'title': 'Glucagon signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04922.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04922'}
# state change
# state change
# state change
# state change
# state change
# {'name': 'path:hsa00563', 'org': 'hsa', 'number': '00563', 'title': 'Glycosylphosphatidylinositol (GPI)-anchor biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00563.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00563'}
# {'name': 'path:hsa04659', 'org': 'hsa', 'number': '04659', 'title': 'Th17 cell differentiation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04659.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04659'}
# {'name': 'path:hsa05221', 'org': 'hsa', 'number': '05221', 'title': 'Acute myeloid leukemia', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05221.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05221'}
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa00601', 'org': 'hsa', 'number': '00601', 'title': 'Glycosphingolipid biosynthesis - lacto and neolacto series', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00601.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00601'}
# {'name': 'path:hsa01523', 'org': 'hsa', 'number': '01523', 'title': 'Antifolate resistance', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01523.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01523'}
# {'name': 'path:hsa03320', 'org': 'hsa', 'number': '03320', 'title': 'PPAR signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03320.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03320'}
# {'name': 'path:hsa01521', 'org': 'hsa', 'number': '01521', 'title': 'EGFR tyrosine kinase inhibitor resistance', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01521.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01521'}
# missing interaction
# {'name': 'path:hsa03450', 'org': 'hsa', 'number': '03450', 'title': 'Non-homologous end-joining', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03450.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03450'}
# {'name': 'path:hsa00603', 'org': 'hsa', 'number': '00603', 'title': 'Glycosphingolipid biosynthesis - globo and isoglobo series', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00603.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00603'}
# {'name': 'path:hsa00830', 'org': 'hsa', 'number': '00830', 'title': 'Retinol metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00830.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00830'}
# {'name': 'path:hsa05223', 'org': 'hsa', 'number': '05223', 'title': 'Non-small cell lung cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05223.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05223'}
# dissociation
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa04115', 'org': 'hsa', 'number': '04115', 'title': 'p53 signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04115.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04115'}
# {'name': 'path:hsa03040', 'org': 'hsa', 'number': '03040', 'title': 'Spliceosome', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03040.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03040'}
# {'name': 'path:hsa04713', 'org': 'hsa', 'number': '04713', 'title': 'Circadian entrainment', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04713.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04713'}
# dissociation
# {'name': 'path:hsa00561', 'org': 'hsa', 'number': '00561', 'title': 'Glycerolipid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00561.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00561'}
# {'name': 'path:hsa04934', 'org': 'hsa', 'number': '04934', 'title': "Cushing's syndrome", 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04934.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04934'}
# missing interaction
# missing interaction
# {'name': 'path:hsa04920', 'org': 'hsa', 'number': '04920', 'title': 'Adipocytokine signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04920.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04920'}
# dissociation
# {'name': 'path:hsa05169', 'org': 'hsa', 'number': '05169', 'title': 'Epstein-Barr virus infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05169.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05169'}
# state change
# dissociation
# dissociation
# {'name': 'path:hsa04510', 'org': 'hsa', 'number': '04510', 'title': 'Focal adhesion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04510.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04510'}
# {'name': 'path:hsa00010', 'org': 'hsa', 'number': '00010', 'title': 'Glycolysis / Gluconeogenesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00010.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00010'}
# {'name': 'path:hsa05168', 'org': 'hsa', 'number': '05168', 'title': 'Herpes simplex infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05168.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05168'}
# dissociation
# dissociation
# {'name': 'path:hsa05140', 'org': 'hsa', 'number': '05140', 'title': 'Leishmaniasis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05140.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05140'}
# dissociation
# dissociation
# {'name': 'path:hsa04921', 'org': 'hsa', 'number': '04921', 'title': 'Oxytocin signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04921.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04921'}
# {'name': 'path:hsa05418', 'org': 'hsa', 'number': '05418', 'title': 'Fluid shear stress and atherosclerosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05418.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05418'}
# dissociation
# {'name': 'path:hsa04060', 'org': 'hsa', 'number': '04060', 'title': 'Cytokine-cytokine receptor interaction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04060.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04060'}
# {'name': 'path:hsa04672', 'org': 'hsa', 'number': '04672', 'title': 'Intestinal immune network for IgA production', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04672.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04672'}
# {'name': 'path:hsa04114', 'org': 'hsa', 'number': '04114', 'title': 'Oocyte meiosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04114.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04114'}
# dissociation
# {'name': 'path:hsa00400', 'org': 'hsa', 'number': '00400', 'title': 'Phenylalanine, tyrosine and tryptophan biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00400.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00400'}
# {'name': 'path:hsa04666', 'org': 'hsa', 'number': '04666', 'title': 'Fc gamma R-mediated phagocytosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04666.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04666'}
# {'name': 'path:hsa05222', 'org': 'hsa', 'number': '05222', 'title': 'Small cell lung cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05222.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05222'}
# dissociation
# dissociation
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa05034', 'org': 'hsa', 'number': '05034', 'title': 'Alcoholism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05034.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05034'}
# {'name': 'path:hsa05020', 'org': 'hsa', 'number': '05020', 'title': 'Prion diseases', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05020.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05020'}
# state change
# state change
# state change
# state change
# {'name': 'path:hsa03460', 'org': 'hsa', 'number': '03460', 'title': 'Fanconi anemia pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03460.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03460'}
# {'name': 'path:hsa04657', 'org': 'hsa', 'number': '04657', 'title': 'IL-17 signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04657.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04657'}
# {'name': 'path:hsa05213', 'org': 'hsa', 'number': '05213', 'title': 'Endometrial cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05213.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05213'}
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa00380', 'org': 'hsa', 'number': '00380', 'title': 'Tryptophan metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00380.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00380'}
# {'name': 'path:hsa04723', 'org': 'hsa', 'number': '04723', 'title': 'Retrograde endocannabinoid signaling', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04723.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04723'}
# {'name': 'path:hsa00592', 'org': 'hsa', 'number': '00592', 'title': 'alpha-Linolenic acid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00592.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00592'}
# {'name': 'path:hsa04910', 'org': 'hsa', 'number': '04910', 'title': 'Insulin signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04910.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04910'}
# dissociation
# {'name': 'path:hsa05165', 'org': 'hsa', 'number': '05165', 'title': 'Human papillomavirus infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05165.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05165'}
# dissociation
# {'name': 'path:hsa00790', 'org': 'hsa', 'number': '00790', 'title': 'Folate biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00790.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00790'}
# {'name': 'path:hsa00785', 'org': 'hsa', 'number': '00785', 'title': 'Lipoic acid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00785.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00785'}
# {'name': 'path:hsa05164', 'org': 'hsa', 'number': '05164', 'title': 'Influenza A', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05164.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05164'}
# dissociation
# {'name': 'path:hsa04520', 'org': 'hsa', 'number': '04520', 'title': 'Adherens junction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04520.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04520'}
# dissociation
# dissociation
# dissociation
# dissociation
# {'name': 'path:hsa00020', 'org': 'hsa', 'number': '00020', 'title': 'Citrate cycle (TCA cycle)', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00020.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00020'}
# {'name': 'path:hsa04911', 'org': 'hsa', 'number': '04911', 'title': 'Insulin secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04911.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04911'}
# {'name': 'path:hsa01100', 'org': 'hsa', 'number': '01100', 'title': 'Metabolic pathways', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01100.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01100'}
# {'name': 'path:hsa05414', 'org': 'hsa', 'number': '05414', 'title': 'Dilated cardiomyopathy (DCM)', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05414.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05414'}
# {'name': 'path:hsa04722', 'org': 'hsa', 'number': '04722', 'title': 'Neurotrophin signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04722.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04722'}
# dissociation
# dissociation
# {'name': 'path:hsa05212', 'org': 'hsa', 'number': '05212', 'title': 'Pancreatic cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05212.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05212'}
# dissociation
# dissociation
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa05206', 'org': 'hsa', 'number': '05206', 'title': 'MicroRNAs in cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05206.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05206'}
# {'name': 'path:hsa04130', 'org': 'hsa', 'number': '04130', 'title': 'SNARE interactions in vesicular transport', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04130.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04130'}
# {'name': 'path:hsa00430', 'org': 'hsa', 'number': '00430', 'title': 'Taurine and hypotaurine metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00430.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00430'}
# {'name': 'path:hsa05010', 'org': 'hsa', 'number': '05010', 'title': "Alzheimer's disease", 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05010.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05010'}
# state change
# {'name': 'path:hsa00140', 'org': 'hsa', 'number': '00140', 'title': 'Steroid hormone biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00140.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00140'}
# {'name': 'path:hsa04330', 'org': 'hsa', 'number': '04330', 'title': 'Notch signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04330.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04330'}
# {'name': 'path:hsa00630', 'org': 'hsa', 'number': '00630', 'title': 'Glyoxylate and dicarboxylate metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00630.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00630'}
# {'name': 'path:hsa05012', 'org': 'hsa', 'number': '05012', 'title': "Parkinson's disease", 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05012.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05012'}
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa00340', 'org': 'hsa', 'number': '00340', 'title': 'Histidine metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00340.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00340'}
# {'name': 'path:hsa04640', 'org': 'hsa', 'number': '04640', 'title': 'Hematopoietic cell lineage', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04640.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04640'}
# {'name': 'path:hsa04668', 'org': 'hsa', 'number': '04668', 'title': 'TNF signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04668.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04668'}
# dissociation
# dissociation
# dissociation
# {'name': 'path:hsa05210', 'org': 'hsa', 'number': '05210', 'title': 'Colorectal cancer', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05210.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05210'}
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# missing interaction
# {'name': 'path:hsa05204', 'org': 'hsa', 'number': '05204', 'title': 'Chemical carcinogenesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05204.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05204'}
# {'name': 'path:hsa04720', 'org': 'hsa', 'number': '04720', 'title': 'Long-term potentiation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04720.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04720'}
# {'name': 'path:hsa00220', 'org': 'hsa', 'number': '00220', 'title': 'Arginine biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00220.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00220'}
# {'name': 'path:hsa05416', 'org': 'hsa', 'number': '05416', 'title': 'Viral myocarditis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05416.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05416'}
# missing interaction
# missing interaction
# {'name': 'path:hsa00591', 'org': 'hsa', 'number': '00591', 'title': 'Linoleic acid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00591.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00591'}
# {'name': 'path:hsa04913', 'org': 'hsa', 'number': '04913', 'title': 'Ovarian steroidogenesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04913.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04913'}
# {'name': 'path:hsa00750', 'org': 'hsa', 'number': '00750', 'title': 'Vitamin B6 metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00750.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00750'}
# {'name': 'path:hsa05166', 'org': 'hsa', 'number': '05166', 'title': 'HTLV-I infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05166.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05166'}
# dissociation
# dissociation
# {'name': 'path:hsa05167', 'org': 'hsa', 'number': '05167', 'title': "Kaposi's sarcoma-associated herpesvirus infection", 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05167.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05167'}
# dissociation
# dissociation
# dissociation
# {'name': 'path:hsa04912', 'org': 'hsa', 'number': '04912', 'title': 'GnRH signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04912.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04912'}
# ...
# {'name': 'path:hsa05310', 'org': 'hsa', 'number': '05310', 'title': 'Asthma', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05310.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05310'}
# {'name': 'path:hsa03013', 'org': 'hsa', 'number': '03013', 'title': 'RNA transport', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03013.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03013'}
# {'name': 'path:hsa04973', 'org': 'hsa', 'number': '04973', 'title': 'Carbohydrate digestion and absorption', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04973.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04973'}
# {'name': 'path:hsa00730', 'org': 'hsa', 'number': '00730', 'title': 'Thiamine metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00730.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00730'}
# {'name': 'path:hsa04218', 'org': 'hsa', 'number': '04218', 'title': 'Cellular senescence', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04218.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04218'}
# {'name': 'path:hsa04966', 'org': 'hsa', 'number': '04966', 'title': 'Collecting duct acid secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04966.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04966'}
# {'name': 'path:hsa04972', 'org': 'hsa', 'number': '04972', 'title': 'Pancreatic secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04972.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04972'}
# {'name': 'path:hsa00533', 'org': 'hsa', 'number': '00533', 'title': 'Glycosaminoglycan biosynthesis - keratan sulfate', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00533.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00533'}
# {'name': 'path:hsa04621', 'org': 'hsa', 'number': '04621', 'title': 'NOD-like receptor signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04621.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04621'}
# dissociation
# dissociation
# {'name': 'path:hsa04392', 'org': 'hsa', 'number': '04392', 'title': 'Hippo signaling pathway - multiple species', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04392.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04392'}
# {'name': 'path:hsa04390', 'org': 'hsa', 'number': '04390', 'title': 'Hippo signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04390.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04390'}
# {'name': 'path:hsa00860', 'org': 'hsa', 'number': '00860', 'title': 'Porphyrin and chlorophyll metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00860.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00860'}
# {'name': 'path:hsa04151', 'org': 'hsa', 'number': '04151', 'title': 'PI3K-Akt signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04151.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04151'}
# {'name': 'path:hsa04623', 'org': 'hsa', 'number': '04623', 'title': 'Cytosolic DNA-sensing pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04623.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04623'}
# dissociation
# {'name': 'path:hsa04145', 'org': 'hsa', 'number': '04145', 'title': 'Phagosome', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04145.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04145'}
# {'name': 'path:hsa04810', 'org': 'hsa', 'number': '04810', 'title': 'Regulation of actin cytoskeleton', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04810.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04810'}
# {'name': 'path:hsa00531', 'org': 'hsa', 'number': '00531', 'title': 'Glycosaminoglycan degradation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00531.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00531'}
# {'name': 'path:hsa03010', 'org': 'hsa', 'number': '03010', 'title': 'Ribosome', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03010.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03010'}
# {'name': 'path:hsa00280', 'org': 'hsa', 'number': '00280', 'title': 'Valine, leucine and isoleucine degradation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00280.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00280'}
# {'name': 'path:hsa04964', 'org': 'hsa', 'number': '04964', 'title': 'Proximal tubule bicarbonate reclamation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04964.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04964'}
# {'name': 'path:hsa04970', 'org': 'hsa', 'number': '04970', 'title': 'Salivary secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04970.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04970'}
# state change
# {'name': 'path:hsa00900', 'org': 'hsa', 'number': '00900', 'title': 'Terpenoid backbone biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00900.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00900'}
# {'name': 'path:hsa05110', 'org': 'hsa', 'number': '05110', 'title': 'Vibrio cholerae infection', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05110.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05110'}
# {'name': 'path:hsa04540', 'org': 'hsa', 'number': '04540', 'title': 'Gap junction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04540.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04540'}
# {'name': 'path:hsa00040', 'org': 'hsa', 'number': '00040', 'title': 'Pentose and glucuronate interconversions', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00040.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00040'}
# {'name': 'path:hsa04971', 'org': 'hsa', 'number': '04971', 'title': 'Gastric acid secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04971.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04971'}
# {'name': 'path:hsa04024', 'org': 'hsa', 'number': '04024', 'title': 'cAMP signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04024.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04024'}
# {'name': 'path:hsa04742', 'org': 'hsa', 'number': '04742', 'title': 'Taste transduction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04742.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04742'}
# {'name': 'path:hsa00524', 'org': 'hsa', 'number': '00524', 'title': 'Neomycin, kanamycin and gentamicin biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00524.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00524'}
# {'name': 'path:hsa04622', 'org': 'hsa', 'number': '04622', 'title': 'RIG-I-like receptor signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04622.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04622'}
# dissociation
# {'name': 'path:hsa04144', 'org': 'hsa', 'number': '04144', 'title': 'Endocytosis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04144.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04144'}
# {'name': 'path:hsa04150', 'org': 'hsa', 'number': '04150', 'title': 'mTOR signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04150.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04150'}
# {'name': 'path:hsa00450', 'org': 'hsa', 'number': '00450', 'title': 'Selenocompound metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00450.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00450'}
# {'name': 'path:hsa00120', 'org': 'hsa', 'number': '00120', 'title': 'Primary bile acid biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00120.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00120'}
# {'name': 'path:hsa01212', 'org': 'hsa', 'number': '01212', 'title': 'Fatty acid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01212.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01212'}
# {'name': 'path:hsa00130', 'org': 'hsa', 'number': '00130', 'title': 'Ubiquinone and other terpenoid-quinone biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00130.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00130'}
# {'name': 'path:hsa04140', 'org': 'hsa', 'number': '04140', 'title': 'Autophagy - animal', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04140.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04140'}
# {'name': 'path:hsa00440', 'org': 'hsa', 'number': '00440', 'title': 'Phosphonate and phosphinate metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00440.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00440'}
# {'name': 'path:hsa03015', 'org': 'hsa', 'number': '03015', 'title': 'mRNA surveillance pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03015.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03015'}
# {'name': 'path:hsa00520', 'org': 'hsa', 'number': '00520', 'title': 'Amino sugar and nucleotide sugar metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00520.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00520'}
# {'name': 'path:hsa04020', 'org': 'hsa', 'number': '04020', 'title': 'Calcium signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04020.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04020'}
# {'name': 'path:hsa00534', 'org': 'hsa', 'number': '00534', 'title': 'Glycosaminoglycan biosynthesis - heparan sulfate / heparin', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00534.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00534'}
# {'name': 'path:hsa04961', 'org': 'hsa', 'number': '04961', 'title': 'Endocrine and other factor-regulated calcium reabsorption', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04961.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04961'}
# {'name': 'path:hsa04975', 'org': 'hsa', 'number': '04975', 'title': 'Fat digestion and absorption', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04975.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04975'}
# {'name': 'path:hsa05100', 'org': 'hsa', 'number': '05100', 'title': 'Bacterial invasion of epithelial cells', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa05100.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa05100'}
# {'name': 'path:hsa04550', 'org': 'hsa', 'number': '04550', 'title': 'Signaling pathways regulating pluripotency of stem cells', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04550.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04550'}
# {'name': 'path:hsa00910', 'org': 'hsa', 'number': '00910', 'title': 'Nitrogen metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00910.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00910'}
# {'name': 'path:hsa00051', 'org': 'hsa', 'number': '00051', 'title': 'Fructose and mannose metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00051.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00051'}
# {'name': 'path:hsa00290', 'org': 'hsa', 'number': '00290', 'title': 'Valine, leucine and isoleucine biosynthesis', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00290.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00290'}
# {'name': 'path:hsa04974', 'org': 'hsa', 'number': '04974', 'title': 'Protein digestion and absorption', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04974.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04974'}
# {'name': 'path:hsa04960', 'org': 'hsa', 'number': '04960', 'title': 'Aldosterone-regulated sodium reabsorption', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04960.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04960'}
# {'name': 'path:hsa04141', 'org': 'hsa', 'number': '04141', 'title': 'Protein processing in endoplasmic reticulum', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04141.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04141'}
# {'name': 'path:hsa04380', 'org': 'hsa', 'number': '04380', 'title': 'Osteoclast differentiation', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04380.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04380'}
# dissociation
# {'name': 'path:hsa03410', 'org': 'hsa', 'number': '03410', 'title': 'Base excision repair', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa03410.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa03410'}
# {'name': 'path:hsa04625', 'org': 'hsa', 'number': '04625', 'title': 'C-type lectin receptor signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04625.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04625'}
# dissociation
# dissociation
# dissociation
# {'name': 'path:hsa00480', 'org': 'hsa', 'number': '00480', 'title': 'Glutathione metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00480.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00480'}
# {'name': 'path:hsa04976', 'org': 'hsa', 'number': '04976', 'title': 'Bile secretion', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04976.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04976'}
# {'name': 'path:hsa04962', 'org': 'hsa', 'number': '04962', 'title': 'Vasopressin-regulated water reabsorption', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04962.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04962'}
# {'name': 'path:hsa00053', 'org': 'hsa', 'number': '00053', 'title': 'Ascorbate and aldarate metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00053.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00053'}
# {'name': 'path:hsa00052', 'org': 'hsa', 'number': '00052', 'title': 'Galactose metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00052.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00052'}
# {'name': 'path:hsa04977', 'org': 'hsa', 'number': '04977', 'title': 'Vitamin digestion and absorption', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04977.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04977'}
# {'name': 'path:hsa04022', 'org': 'hsa', 'number': '04022', 'title': 'cGMP-PKG signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04022.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04022'}
# {'name': 'path:hsa04744', 'org': 'hsa', 'number': '04744', 'title': 'Phototransduction', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04744.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04744'}
# {'name': 'path:hsa04750', 'org': 'hsa', 'number': '04750', 'title': 'Inflammatory mediator regulation of TRP channels', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04750.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04750'}
# {'name': 'path:hsa00250', 'org': 'hsa', 'number': '00250', 'title': 'Alanine, aspartate and glutamate metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00250.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00250'}
# {'name': 'path:hsa00330', 'org': 'hsa', 'number': '00330', 'title': 'Arginine and proline metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00330.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00330'}
# {'name': 'path:hsa04630', 'org': 'hsa', 'number': '04630', 'title': 'Jak-STAT signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04630.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04630'}
# state change
# {'name': 'path:hsa04142', 'org': 'hsa', 'number': '04142', 'title': 'Lysosome', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04142.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04142'}
# {'name': 'path:hsa04340', 'org': 'hsa', 'number': '04340', 'title': 'Hedgehog signaling pathway', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa04340.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa04340'}
# {'name': 'path:hsa00640', 'org': 'hsa', 'number': '00640', 'title': 'Propanoate metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa00640.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa00640'}
# {'name': 'path:hsa01210', 'org': 'hsa', 'number': '01210', 'title': '2-Oxocarboxylic acid metabolism', 'image': 'http://www.kegg.jp/kegg/pathway/hsa/hsa01210.png', 'link': 'http://www.kegg.jp/kegg-bin/show_pathway?hsa01210'}

# %%
import pickle

pickle.dump(graphs, open("KGML_networkx_graphs.v0.1.pickle", "wb"))
