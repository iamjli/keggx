# %%
import sys
sys.path.insert(0, "../src/")
from KEGGX import *

# %%
pathway_id = 'hsa03030'

pathway = KEGGX("../data/human_KGML/{}.xml".format(pathway_id))

# %%
pathway.node_attributes_df.head()
# Out:
#         name                                     aliases  type     x     y  \
# id
# 1       LIG1                                        LIG1  gene  1158  1231
# 2       FEN1                      FEN1, FEN-1, MF1, RAD2  gene  1081  1231
# 3       DNA2                          DNA2, DNA2L, hDNA2  gene  1003  1230
# 4   RNASEH2A  RNASEH2A, AGS4, JUNB, RNASEHI, RNHIA, RNHL  gene  1067  1174
# 5   RNASEH2B                       RNASEH2B, AGS2, DLEU8  gene  1113  1174
#
#    height width      shape  bgcolor  fgcolor
# id
# 1      17    46  rectangle  #BFFFBF  #000000
# 2      17    46  rectangle  #BFFFBF  #000000
# 3      17    46  rectangle  #BFFFBF  #000000
# 4      17    46  rectangle  #BFFFBF  #000000
# 5      17    46  rectangle  #BFFFBF  #000000

# %%
graph = pathway.output_KGML_as_graphml('{}.graphml'.format(pathway_id))

# %%
graph = pathway.output_KGML_as_graphml('{}_detailed.graphml'.format(pathway_id), detailed=True)

# %%
pathway.node_attributes_df.head()
# Out:
#        name                                aliases      type    x    y height  \
# id
# 14    ALDOA       ALDOA, ALDA, GSD12, HEL-S-87p...      gene  483  407     17
# 38    ALDH2         ALDH2, ALDH-E2, ALDHI, ALDM...      gene  284  948     17
# 40  ALDH3A1             ALDH3A1, ALDH3, ALDHIII...      gene  259  969     17
# 41   C00033                                 C00033  compound  146  958      8
# 45   AKR1A1  AKR1A1, ALDR1, ALR, ARM, DD3, HEL-S-6      gene  487  948     17
#
#    width      shape  bgcolor  fgcolor
# id
# 14    46  rectangle  #BFFFBF  #000000
# 38    46  rectangle  #BFFFBF  #000000
# 40    46  rectangle  #BFFFBF  #000000
# 41     8     circle  #FFFFFF  #000000
# 45    46  rectangle  #BFFFBF  #000000

# %%
pathway.edge_attributes_df.head()
# Out:
#   source target  effect  indirect modification       type
# 0     38    101       1         0               rn:R00710
# 1     38     41       1         0               rn:R00710
# 2     40    101       1         0               rn:R00711
# 3     40     41       1         0               rn:R00711
# 4     45     97       1         0               rn:R00746

# %%
indices = pathway.node_attributes_df[pathway.node_attributes_df['type'] == 'compound'].index
indices
# Out:
# Index(['41', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93',
#        '94', '95', '96', '97', '98', '99', '100', '101', '102', '103', '104',
#        '105', '106', '107', '108', '113', '125', '130', '136'],
#       dtype='object', name='id')

# %%
pathway.edge_attributes_df[(pathway.edge_attributes_df['source'].isin(indices)) | (pathway.edge_attributes_df['target'].isin(indices))]
# Out:
#    source target  effect  indirect modification   type
# 43     53     72       1         0               ECrel
# 44     72     73       1         0               ECrel
# 52     36     37       1         1               PCrel
# 54     35     36       1         1               PCrel

# %%
directed_edge_attributes_df = pathway._get_directed_edge_attributes_as_dataframe(pathway.edge_attributes_df)

# %%
directed_edge_attributes_df.head()
# Out:
#    effect  indirect modification source target       type
# 0       1         0                  38    101  rn:R00710
# 1       1         0                  38     41  rn:R00710
# 2       1         0                  40    101  rn:R00711
# 3       1         0                  40     41  rn:R00711
# 4       1         0                  45     97  rn:R00746

# %%
directed_edge_attributes_df[directed_edge_attributes_df['source'] == '41']
# Out:
#     effect  indirect modification source target       type
# 67       1         0                  41    131  rn:R00235

# %%
directed_edge_attributes_df[directed_edge_attributes_df['target'] == '41']
# Out:
#    effect  indirect modification source target       type
# 1       1         0                  38     41  rn:R00710
# 3       1         0                  40     41  rn:R00711

# %%
directed_edge_attributes_df[(directed_edge_attributes_df['source'].isin(indices)) | (directed_edge_attributes_df['target'].isin(indices))]
# Out:
#     effect  indirect modification source target                 type
# 0        1         0                  38    101            rn:R00710
# 1        1         0                  38     41            rn:R00710
# 2        1         0                  40    101            rn:R00711
# 3        1         0                  40     41            rn:R00711
# 4        1         0                  45     97            rn:R00746
# 5        1         0                  45    101            rn:R00746
# 6        1         0                  46     97            rn:R00754
# 7        1         0                  46    101            rn:R00754
# 8        1         0                  98     48            rn:R00014
# 9        1         0                 136     48            rn:R00014
# 10       1         0                  48     99            rn:R00014
# 11       1         0                  96     49            rn:R03270
# 12       1         0                  99     49            rn:R03270
# ...

# %%
for compound_id in ['35', '36', '72']: 
    
    targets = directed_edge_attributes_df[directed_edge_attributes_df['target'] == compound_id]
    sources = directed_edge_attributes_df[directed_edge_attributes_df['source'] == compound_id]
